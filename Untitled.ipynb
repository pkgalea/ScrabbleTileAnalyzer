# %%
# %load_ext autoreload
# %autoreload 2

from RackEvaluator import RackEvaluator, TileCondition
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [autoreload of RackEvaluator failed: Traceback (most recent call last):
#   File "/home/pkgalea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/pkgalea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/home/pkgalea/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/pkgalea/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/pkgalea/Galvanize/scrabble/RackEvaluator.py", line 113
#     report += "Score p-value: %3f" % stats.ttest_ind(control.turn_score, test.turn_score, equal_var=False).pvalue
#     ^
# IndentationError: unexpected indent
# ]

# %%
re = RackEvaluator([TileCondition('M', 0, "==")], [TileCondition('M', 1, "<=")])
axes, report = re.evaluate()
print(report)
# Out:
# Results:
#      mean scores with Exactly 0 M's: 34.08, (n=319203)
#      mean score with 1 or less M's: 34.12, (n=362208)
# Test for equality of means:
#      We do not have enough evidence to reject the hypothesis that the two distributions are equal.     (p-value: 0.5109772111608303)
#
# Measure of effect:
# I can say with 95% confidence that a rack with 1 or less M's will score between [-0.07106807423697364, 0.15106807423697194] points than a rack with Exactly 0 M's
