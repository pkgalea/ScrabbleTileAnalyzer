# %%
# %load_ext autoreload
# %autoreload 2

from RackEvaluator import RackEvaluator, TileCondition
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
re = RackEvaluator([TileCondition('M', 1, "<")])
axes, report = re.evaluate()
print(report)
# Out:
# mean scores with Less than 1 M's: 34.08, (319203)
# mean score with 1 or more M's: 34.24, (44258)
# Score p-value: 0.152143
